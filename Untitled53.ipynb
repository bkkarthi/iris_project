# %%
import pandas as pd
mk=pd.read_csv("Downloads/ML Program.csv")

# %%
mk
# Out:
#   Sky     AirTemp   Humidity   Wind     Water   Forecast EnjoySport
# 0  Sunny   Warm      Normal     Strong   Warm    ...
# 1  Sunny   Warm      High       Strong   Warm    ...
# 2  Rainy   Cold      High       Strong   Warm    ...
# 3  Sunny   Warm      High       Strong   Cool    ...
# 4

# %%
import pandas as pd
mk=pd.read_csv("Downloads/ML Program.csv")

# %% [markdown]
# mk

# %%
mk
# Out:
#        import numpy as np import pandas as pd data =
# 0  pd.DataFrame(data=pd.read_csv('ENJOYSPORT.csv'...
# 1  np.array(data.iloc[:,0:-1]) print(concepts) ta...
# 2  learn(concepts, target): specific_h = concepts...
# 3  general_h") print(specific_h) general_h = [["?...
# 4  range(len(specific_h))] print(general_h) for i...
# 5  in range(len(specific_h)): if h[x] != specific...

# %%
import pandas as pd

# %%
import pandas as pd
mk=pd.read_csv(r"C:\Users\STUDENT\Downloads\labels_my-project-name_2023-08-03-12-34-00.csv")
mk
# Out:
#     label_name  bbox_x  bbox_y  bbox_width  bbox_height  \
# 0       karthi    3428     328        1337         1123
# 1  karunakaran    2453     240         975         1226
# 2    madhappan    1226     291        1212         1197
# 3        surya     340     336         805         1101
#
#                                 image_name  image_width  image_height
# 0  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 1  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 2  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 3  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829

# %%
mk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
mk.sum()
# Out:
# label_name                        karthikarunakaranmadhappansurya
# bbox_x                                                       7447
# bbox_y                                                       1195
# bbox_width                                                   4329
# bbox_height                                                  4647
# image_name      david-tomaseti-Vw2HZQ1FGjU-unsplash.jpgdavid-t...
# image_width                                                 19860
# image_height                                                11316
# dtype: object

# %%
mk.isnull().sum()
# Out:
# label_name      0
# bbox_x          0
# bbox_y          0
# bbox_width      0
# bbox_height     0
# image_name      0
# image_width     0
# image_height    0
# dtype: int64

# %%
mk
# Out:
#     label_name  bbox_x  bbox_y  bbox_width  bbox_height  \
# 0       karthi    3428     328        1337         1123
# 1  karunakaran    2453     240         975         1226
# 2    madhappan    1226     291        1212         1197
# 3        surya     340     336         805         1101
#
#                                 image_name  image_width  image_height
# 0  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 1  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 2  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 3  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829

# %%
sns.pairplot(mk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/3260361686.py in <module>
# ----> 1 sns.pairplot(mk)
#
# NameError: name 'sns' is not defined

# %%
mk.pairplot(cam)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/3975900266.py in <module>
# ----> 1 mk.pairplot(cam)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pairplot'

# %%
import pandas as pd
mk=pd.read_csv("Downloads/ML Program.csv")

# %%
mk
# Out:
#        import numpy as np import pandas as pd data =
# 0  pd.DataFrame(data=pd.read_csv('ENJOYSPORT.csv'...
# 1  np.array(data.iloc[:,0:-1]) print(concepts) ta...
# 2  learn(concepts, target): specific_h = concepts...
# 3  general_h") print(specific_h) general_h = [["?...
# 4  range(len(specific_h))] print(general_h) for i...
# 5  in range(len(specific_h)): if h[x] != specific...

# %%
sns.pairplot(mk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/3260361686.py in <module>
# ----> 1 sns.pairplot(mk)
#
# NameError: name 'sns' is not defined

# %%
mk.pairplot(sns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/1144279127.py in <module>
# ----> 1 mk.pairplot(sns)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pairplot'

# %%
sns.pairplot(mk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/3260361686.py in <module>
# ----> 1 sns.pairplot(mk)
#
# NameError: name 'sns' is not defined

# %%
import pandas as pd
cam=pd.read_csv(r"C:\Users\STUDENT\Downloads\labels_my-project-name_2023-08-03-12-34-00.csv")
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.model_selection import train_test_split

# %%
cam
# Out:
#     label_name  bbox_x  bbox_y  bbox_width  bbox_height  \
# 0       karthi    3428     328        1337         1123
# 1  karunakaran    2453     240         975         1226
# 2    madhappan    1226     291        1212         1197
# 3        surya     340     336         805         1101
#
#                                 image_name  image_width  image_height
# 0  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 1  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 2  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829
# 3  david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg         4965          2829

# %%
print info()
# Out:
#   File "C:\Users\STUDENT\AppData\Local\Temp/ipykernel_6016/2752499790.py", line 1
#     print info()
#           ^
# SyntaxError: invalid syntax

# %%
cam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
cam.sum()
# Out:
# label_name                        karthikarunakaranmadhappansurya
# bbox_x                                                       7447
# bbox_y                                                       1195
# bbox_width                                                   4329
# bbox_height                                                  4647
# image_name      david-tomaseti-Vw2HZQ1FGjU-unsplash.jpgdavid-t...
# image_width                                                 19860
# image_height                                                11316
# dtype: object

# %%
cam.isnull().sum()
# Out:
# label_name      0
# bbox_x          0
# bbox_y          0
# bbox_width      0
# bbox_height     0
# image_name      0
# image_width     0
# image_height    0
# dtype: int64

# %%
sns.pairplot(cam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/2291848832.py in <module>
# ----> 1 sns.pairplot(cam)
#
# NameError: name 'sns' is not defined

# %%
cam.pairplot(sns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/2158017741.py in <module>
# ----> 1 cam.pairplot(sns)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pairplot'

# %%
import seaborn as sns

# %%
sns.pairplot(cam)

# %%
sns.displot(data=cam)

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as img

# %%
testimg=img.imread("Downloads/david-tomaseti-Vw2HZQ1FGjU-unsplash.jpg")
plt.imshow(testimg)

# %%
import cv2

# %%
Start_point=(4,4)
End_point=(220,220)
color=(225,0,0)
thickness=9

# %%
testimg=cv2.rectangle(testimg,start_point,End_point,color,thickness)
plt.imshow(testimg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6016/1545961857.py in <module>
# ----> 1 testimg=cv2.rectangle(testimg,start_point,End_point,color,thickness)
#       2 plt.imshow(testimg)
#
# NameError: name 'start_point' is not defined
